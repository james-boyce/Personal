# %%
import os
import pandas as pd

# %%
## CHANGE THIS FOR EACH FILE (0-45)
FILE_NO =1

# %% [markdown]
# ## Import and Explore Dataset

# %%
df = pd.read_feather(str('./Data/Datasets/file' + str(FILE_NO) + '.feather'))

# %%
df.shape
# Out:
# (3510276, 15)

# %%
df.dtypes
# Out:
# marketplace           object
# customer_id            int64
# review_id             object
# product_id            object
# product_parent         int64
# product_title         object
# product_category      object
# star_rating          float64
# helpful_votes        float64
# total_votes          float64
# vine                  object
# verified_purchase     object
# review_headline       object
# review_body           object
# review_date           object
# dtype: object

# %%
df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US     36075342   RAB23OVFNCXZQ  B00LPRXQ4Y       339193102
# 1          US     42462164  R3NORADVJO6IE6  B000C7S0TO       907684644
# 2          US     21241933  R299F4SO98S5OO  B000CO9WE4       752246352
# 3          US     52570308  R2DA9DOT03UW6I  B000GKD5NI       105401756
# 4          US     38200102  R2OGCH681EQHU6  B009SDA7TE       728471129
#
#                                        product_title product_category  \
# 0  17" 2003-2006 Ford EXPEDITION Ford F150 2004-2...       Automotive
# 1  Spectra Premium CU1909 Complete Radiator for T...       Automotive
# 2  K&N E-4665 High Performance Replacement Indust...       Automotive
# 3                       Suncutters Rear Window Shade       Automotive
# 4  Lug Nuts Landcruiser Tundra OEM Mag 14x1.5 Thr...       Automotive
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0          1.0            0.0          0.0    N                 Y
# 1          5.0            0.0          0.0    N                 Y
# 2          5.0            1.0          1.0    N                 Y
# 3          5.0            2.0          3.0    N                 Y
# 4          5.0            0.0          0.0    N                 Y
#
#                                      review_headline  \
# 0                                    As it was used,
# 1                                         Five Stars
# 2  Great fit and performance on the surface drive...
# 3  Good for the price. Fits fairly good on 2010 T...
# 4                                         Five Stars
#
#                                          review_body review_date
# 0  As it was used, the method that Ford used to a...  2015-08-31
# 1  Put it in fine, no problems. Shipping was dece...  2015-08-31
# 2        Fit wonderfully on my 36HP Pro-Drive motor.  2015-08-31
# 3  Good for the price!  So far I have put it up i...  2015-08-31
# 4  Fit perfectly on my 2012 Tundra with stock alu...  2015-08-31

# %%
## Check for null
df.isnull().sum().sum()
# Out:
# 0

# %%
##Check for Duplicates
data_duplicates = df[df.duplicated(subset=['product_id' ,'star_rating','review_headline', 'review_body'])]
print('\033[34m' + '\033[1m' + '\033[4m' + "\nThe number of duplicate review_body in dataset:\n" + '\033[0m' + \
    str(data_duplicates.shape[0]))
# Out:
# The number of duplicate review_body in dataset:
# 4449

# %%
#Drop duplicates in dataset and reset index
clean_df = df

clean_df.drop_duplicates(subset = ['product_id', 'star_rating', 'review_headline', 'review_body'], keep='first', inplace=True)
clean_df = clean_df.reset_index()

##Check for Duplicates
data_duplicates = clean_df[clean_df.duplicated(subset=['product_id' ,'star_rating','review_headline', 'review_body'])]
print('\033[34m' + '\033[1m' + '\033[4m' + "\nThe number of duplicate review_body in dataset:\n" + '\033[0m' + \
    str(data_duplicates.shape[0]))
# Out:
# The number of duplicate review_body in dataset:
# 0

# %% [markdown]
# # Pre-Data Preperation Calculations
# ## Calculate Customer Activity and Helpful/Total votes ---> Then Export to file

# %%
"""THESE FILES WILL BE COMBINED LATER TO CALCULATE ACTIVITY AND REPUTATION OF FULL DATASET"""

customer = clean_df.groupby('customer_id')
activity = customer['review_id'].agg('count')
helpful = customer['helpful_votes'].agg('sum')
total = customer['total_votes'].agg('sum')


customer_df = pd.DataFrame({'customer_id':activity.index, 'Activity':activity.values, 'Helpful_Votes':helpful.values, 'Total_Votes':total.values})

customer_df
# Out:
#          customer_id  Activity  Helpful_Votes  Total_Votes
# 0              10004         1            0.0          1.0
# 1              10014         1            1.0          2.0
# 2              10015         1            1.0          1.0
# 3              10035         1            0.0          0.0
# 4              10059         1            0.0          0.0
# ...              ...       ...            ...          ...
# 1904341     53096518         1            0.0          1.0
# 1904342     53096540         1            2.0          3.0
# 1904343     53096549         1            0.0          0.0
# 1904344     53096553         1           67.0         68.0
# 1904345     53096570         1            3.0          3.0
#
# [1904346 rows x 4 columns]

# %%
customer_df.to_feather(str('./Data/Customer_Data/customer_' + str(FILE_NO) + '.feather'))

# %% [markdown]
# # Data Prepertation
# ## Prepare data columns

# %%
prep_df = clean_df

# %%
## Remove Columns that are not to be used
prep_df = prep_df.drop(["marketplace", "product_parent", ], axis = 1)

# %%
##Convert Dates to Date type
prep_df['review_date'] = pd.to_datetime(prep_df['review_date'])

# %% [markdown]
# ## Filter for Products with earliest review in 2015

# %%
#Group products together
product_dates = prep_df.groupby('product_id')

#Create list of the earliest review date of each product 
min_date = product_dates['review_date'].agg('min')

#Convert to dataframe
min_df = min_date.to_frame(name='Min').reset_index()

#Add year to the min_df
min_df['Year'] = pd.DatetimeIndex(min_df['Min']).year

# %%
#Filter for only products with the earliest review in 2015 (recent products)
#Reset the index
recent_products = min_df[min_df['Year'] == 2015]
recent_products = recent_products.reset_index(drop=True)

# %%
recent_products
# Out:
#         product_id        Min  Year
# 0       0983270112 2015-06-04  2015
# 1       0984527281 2015-01-15  2015
# 2       1453080279 2015-01-26  2015
# 3       1564137503 2015-05-03  2015
# 4       1609675932 2015-06-26  2015
# ...            ...        ...   ...
# 215118  B014J838AC 2015-03-06  2015
# 215119  B014J8CQ9Q 2015-05-02  2015
# 215120  B01D42TYFC 2015-08-05  2015
# 215121  B01M75GUJB 2015-06-12  2015
# 215122  B01MZ8BUY3 2015-07-22  2015
#
# [215123 rows x 3 columns]

# %%
#Create a reduced dataframe with only the products in recent_product dataframe
reduced_df = pd.merge(recent_products, prep_df, on="product_id", how='left')
reduced_df
# Out:
#         product_id        Min  Year    index  customer_id       review_id  \
# 0       0983270112 2015-06-04  2015   502145     12300008  R3DCH5Y6T4ROEW
# 1       0984527281 2015-01-15  2015   274874     39921872  R3SDFQSH1IULYH
# 2       0984527281 2015-01-15  2015  1222130     51019815  R1B7F0FR48QGYO
# 3       1453080279 2015-01-26  2015  1178318     48091777  R1P313WDOPIWGO
# 4       1564137503 2015-05-03  2015   672552     13863876  R3RXZA4ZCMKF5W
# ...            ...        ...   ...      ...          ...             ...
# 318956  B014J838AC 2015-03-06  2015   978258     46053194  R1ZNV0DP5RSG0L
# 318957  B014J8CQ9Q 2015-05-02  2015   679038     46053194  R2F7HDZV2XO6KJ
# 318958  B01D42TYFC 2015-08-05  2015   157903     35353346   RR9SMJM7DGR7I
# 318959  B01M75GUJB 2015-06-12  2015   456956     51367435   RB9JCTHQW5VQD
# 318960  B01MZ8BUY3 2015-07-22  2015   233873      2383044  R1G9DZZG2FWRIZ
#
#                                             product_title product_category  \
# 0         Utah Backcountry Discovery Route Motorcycle Map       Automotive
# 1       Word Teasers Learn the Truth Behind Old Wives ...       Automotive
# 2       Word Teasers Learn the Truth Behind Old Wives ...       Automotive
# 3       DISNEY FROZEN GRAB & GO MINI PLAY PACK WITH CR...       Automotive
# 4       DENSO # 3403 IRIDIUM PLATINUM power pack Spark...       Automotive
# ...                                                   ...              ...
# 318956  SpareCover ABC Series abc-CR-V-27-Tire Cover w...       Automotive
# 318957             SpareCover abc-Rav4-28-pink ABC Series       Automotive
# 318958  DBPOWER 600A Peak 18000mAh Portable Car Jump S...       Automotive
# 318959   Meguiar's Heavy Duty Headlight Restoration Kit.1       Automotive
# 318960         DBPOWER 12000mAh Portable Car Jump Starter       Automotive
#
#         star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0               5.0            0.0          1.0    N                 Y
# 1               5.0            3.0          5.0    N                 Y
# 2               5.0            2.0          4.0    N                 Y
# 3               2.0            0.0          1.0    N                 Y
# 4               5.0            0.0          0.0    N                 Y
# ...             ...            ...          ...  ...               ...
# 318956          5.0           21.0         21.0    N                 Y
# 318957          5.0           15.0         16.0    N                 Y
# 318958          4.0            0.0          0.0    N                 N
# 318959          5.0            0.0          0.0    Y                 N
# 318960          5.0            1.0          1.0    N                 N
#
#                                           review_headline  \
# 0                                              Five Stars
# 1                                              Five Stars
# 2                                              Five Stars
# 3                                               Two Stars
# 4                                              Five Stars
# ...                                                   ...
# 318956  GREAT US made tire cover ... Be sure your cove...
# 318957  GREAT US made tire cover ... Be sure your cove...
# 318958                      Battery jumper plus much more
# 318959  Spray on coating saves work, looks great, and ...
# 318960                                         Great tool
#
#                                               review_body review_date
# 0                                               xlnt sale  2015-06-04
# 1       my son loves this kind of stuff and uses it da...  2015-07-15
# 2                                               Good game  2015-01-15
# 3                                          Disappointing!  2015-01-26
# 4                   On time and installed on the Tundra!!  2015-05-03
# ...                                                   ...         ...
# 318956  GREAT US made tire cover ... Be sure your cove...  2015-03-06
# 318957  GREAT US made tire cover ... Be sure your cove...  2015-05-02
# 318958  What amazes me as it has only been a short tim...  2015-08-05
# 318959  G2000 and G2970 kits are identical ... both ha...  2015-06-12
# 318960  Great set for the car.. I like to keep it in m...  2015-07-22
#
# [318961 rows x 16 columns]

# %% [markdown]
# ## Filter for 32 <= reviews <= 100

# %%
##Find Number of reviews per product
#Group by products
product_reviews = reduced_df.groupby('product_id')

#Count the number of review id's (reviews) per product
product_review_count = product_reviews['review_id'].agg('count')

#Convert to dataframe and reset index
count_df = pd.DataFrame({'product_id':product_review_count.index, 'Review_count':product_review_count.values})
count_df.shape
# Out:
# (215123, 2)

# %%
#Filter out entries with less than 10 reviews
filter_count = count_df[count_df['Review_count'] >= 32]
filter_count = filter_count[filter_count['Review_count'] <= 100]
filter_count = filter_count.reset_index(drop=True)
filter_count
# Out:
#       product_id  Review_count
# 0     B000C8XRHS            15
# 1     B000GVDKZU            14
# 2     B000KZ0HYY            15
# 3     B000N3CP7A            13
# 4     B000QIQU5K            11
# ...          ...           ...
# 1462  B011KHEHWS            10
# 1463  B011Q18D14            30
# 1464  B012YMDPHG            11
# 1465  B0130NLX8G            11
# 1466  B013ME9PII            11
#
# [1467 rows x 2 columns]

# %%
#Create a reduced dataframe with only the products in filter_count dataframe
filter_df = pd.merge(filter_count, reduced_df, on="product_id", how='left')
filter_df
# Out:
#        product_id  Review_count        Min  Year   index  customer_id  \
# 0      B000C8XRHS            15 2015-02-17  2015   87322      2611776
# 1      B000C8XRHS            15 2015-02-17  2015  429868      9535324
# 2      B000C8XRHS            15 2015-02-17  2015  564077      7753330
# 3      B000C8XRHS            15 2015-02-17  2015  576953     30072229
# 4      B000C8XRHS            15 2015-02-17  2015  578183      5146457
# ...           ...           ...        ...   ...     ...          ...
# 28461  B013ME9PII            11 2015-08-16  2015   81447     46464962
# 28462  B013ME9PII            11 2015-08-16  2015   91506     20265694
# 28463  B013ME9PII            11 2015-08-16  2015   91698     51251197
# 28464  B013ME9PII            11 2015-08-16  2015   93005     44623952
# 28465  B013ME9PII            11 2015-08-16  2015   94631     13941233
#
#             review_id                                    product_title  \
# 0      R2B2OLPECLOLMX  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 1      R1C9J9OPOHNLUJ  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 2      R3UCWQAU9OLH58  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 3      R3E8WO60I4YNDO  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 4      R3U6GK93RTV34K  Wagner Lighting 9011 Halogen Capsule - Box of 1
# ...               ...                                              ...
# 28461  R1JKAJL1912RPL                                      Helmet Hook
# 28462  R18FBBHIP6UD7M                                      Helmet Hook
# 28463   RZ00R4KPPDQ6O                                      Helmet Hook
# 28464   RUVNEVCVLVEG3                                      Helmet Hook
# 28465  R3A9L0DGVTEE5I                                      Helmet Hook
#
#       product_category  star_rating  helpful_votes  total_votes vine  \
# 0           Automotive          5.0            1.0          1.0    N
# 1           Automotive          5.0            0.0          0.0    N
# 2           Automotive          5.0            0.0          0.0    N
# 3           Automotive          5.0            1.0          1.0    N
# 4           Automotive          4.0            0.0          0.0    N
# ...                ...          ...            ...          ...  ...
# 28461       Automotive          5.0            1.0          1.0    N
# 28462       Automotive          5.0            1.0          1.0    N
# 28463       Automotive          5.0            1.0          1.0    N
# 28464       Automotive          5.0            1.0          1.0    N
# 28465       Automotive          5.0            4.0          4.0    N
#
#       verified_purchase                                    review_headline  \
# 0                     Y                                      Good purchase
# 1                     Y  half the price of the retail product, the exac...
# 2                     Y                                         Five Stars
# 3                     Y  Both light up fine however. Shipping took a we...
# 4                     Y                                         Four Stars
# ...                 ...                                                ...
# 28461                 N                                 A simple solution.
# 28462                 N                                   Awesome product!
# 28463                 N                      Simple idea that works great!
# 28464                 N                           Cool idea and execution.
# 28465                 N                             These hooks are GREAT!
#
#                                              review_body review_date
# 0      Bulbs came as described. Installed them and th...  2015-08-17
# 1      packaged in generic boxes, but these are the r...  2015-06-17
# 2                           good light, very bright also  2015-05-24
# 3      Replace a 9005/HB3 bulb with this Wagner light...  2015-05-21
# 4                                           Great price.  2015-05-21
# ...                                                  ...         ...
# 28461  Having dropped a helmet or two in my 40+ years...  2015-08-18
# 28462  This is such a well made, clever, and simple d...  2015-08-16
# 28463  This is a great little invention that solves t...  2015-08-16
# 28464  I bought these when they first came out a coup...  2015-08-16
# 28465  These Helmet Hooks are GREAT! I have one on my...  2015-08-16
#
# [28466 rows x 17 columns]

# %% [markdown]
# ## Calculate Review Order

# %%
##Set order Dataframe
order_df = filter_df

# %%
## Sort values by product then by date (earliest - oldest)
order_df = order_df.sort_values(['product_id', 'review_date'], ascending=[True, True])

# %%
## Generate a list of the order of reviews
prev_row = order_df['product_id'][0]
order_num = 1
order_list = []

for index, row in order_df.iterrows():
    if prev_row == row['product_id']:
        order_list.append(order_num)
        order_num += 1
        prev_row = row['product_id']
    else: 
        order_num = 1
        order_list.append(order_num)
        order_num += 1
        prev_row = row['product_id']

# %%
## Insert the list into df
order_df.insert(17, 'Review_Order', order_list)

# %%
order_df.head()
# Out:
#     product_id  Review_count        Min  Year    index  customer_id  \
# 14  B000C8XRHS            15 2015-02-17  2015  1075906     50884444
# 13  B000C8XRHS            15 2015-02-17  2015   940252     37453533
# 12  B000C8XRHS            15 2015-02-17  2015   881869     36855749
# 11  B000C8XRHS            15 2015-02-17  2015   870581      2586124
# 10  B000C8XRHS            15 2015-02-17  2015   861058     13517324
#
#          review_id                                    product_title  \
# 14   RJ8BBM1YQS1ZJ  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 13  R1V1CATWFK58NI  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 12  R1J9I5WN2W5YM4  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 11  R30FL2MVJFRLH3  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 10   RTBNC9X1DCQJD  Wagner Lighting 9011 Halogen Capsule - Box of 1
#
#    product_category  star_rating  helpful_votes  total_votes vine  \
# 14       Automotive          5.0            5.0          6.0    N
# 13       Automotive          5.0            0.0          1.0    N
# 12       Automotive          5.0            1.0          1.0    N
# 11       Automotive          5.0            1.0          1.0    N
# 10       Automotive          5.0            0.0          0.0    N
#
#    verified_purchase              review_headline  \
# 14                 Y  Genuine Philips 9011 bulbs!
# 13                 Y                   Five Stars
# 12                 Y            Truely excellent!
# 11                 Y     Great deal for the price
# 10                 Y                 Great bulbs.
#
#                                           review_body review_date  \
# 14  Awesome deal! I saw that there was a long dela...  2015-02-17
# 13  Brighter than stock 9005, retains proper focus...  2015-03-14
# 12  Well worth the money if your looking for a bri...  2015-03-25
# 11  These are actually Phillips 9011!!!<br />Great...  2015-03-27
# 10              Work great.  These are the real deal.  2015-03-29
#
#     Review_Order
# 14             1
# 13             2
# 12             3
# 11             4
# 10             5

# %% [markdown]
# ## Filter Vine and Un-Verified Reviews

# %%
verified_df = order_df[order_df['verified_purchase'] == 'Y']

# %%
verified_df = verified_df[verified_df['vine'] == 'N']

# %%
verified_df.shape
# Out:
# (24282, 18)

# %% [markdown]
# ## Calculate Helpfulness per review

# %%
#Function to find the helpfulness index
def helpIndex(row):
    if row['total_votes'] == 0:
        val = 0
    else:
        val = (row['helpful_votes'] / row['total_votes']) 
    return val

# %%
## Generate helpfulness index for each review
verified_df['helpfulness_index'] = verified_df.apply(helpIndex, axis=1)
verified_df = verified_df.round(2)
verified_df.head()
# Out:
#     product_id  Review_count        Min  Year    index  customer_id  \
# 14  B000C8XRHS            15 2015-02-17  2015  1075906     50884444
# 13  B000C8XRHS            15 2015-02-17  2015   940252     37453533
# 12  B000C8XRHS            15 2015-02-17  2015   881869     36855749
# 11  B000C8XRHS            15 2015-02-17  2015   870581      2586124
# 10  B000C8XRHS            15 2015-02-17  2015   861058     13517324
#
#          review_id                                    product_title  \
# 14   RJ8BBM1YQS1ZJ  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 13  R1V1CATWFK58NI  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 12  R1J9I5WN2W5YM4  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 11  R30FL2MVJFRLH3  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 10   RTBNC9X1DCQJD  Wagner Lighting 9011 Halogen Capsule - Box of 1
#
#    product_category  star_rating  helpful_votes  total_votes vine  \
# 14       Automotive          5.0            5.0          6.0    N
# 13       Automotive          5.0            0.0          1.0    N
# 12       Automotive          5.0            1.0          1.0    N
# 11       Automotive          5.0            1.0          1.0    N
# 10       Automotive          5.0            0.0          0.0    N
#
#    verified_purchase              review_headline  \
# 14                 Y  Genuine Philips 9011 bulbs!
# 13                 Y                   Five Stars
# 12                 Y            Truely excellent!
# 11                 Y     Great deal for the price
# 10                 Y                 Great bulbs.
#
#                                           review_body review_date  \
# 14  Awesome deal! I saw that there was a long dela...  2015-02-17
# 13  Brighter than stock 9005, retains proper focus...  2015-03-14
# 12  Well worth the money if your looking for a bri...  2015-03-25
# 11  These are actually Phillips 9011!!!<br />Great...  2015-03-27
# 10              Work great.  These are the real deal.  2015-03-29
#
#     Review_Order  helpfulness_index
# 14             1               0.83
# 13             2               0.00
# 12             3               1.00
# 11             4               1.00
# 10             5               0.00

# %% [markdown]
# ## Calculate Review and Summary Length

# %%
#Add Review Length
verified_df['Text_Length'] = verified_df['review_body'].str.split().str.len()
verified_df['Summary_Length'] = verified_df['review_headline'].str.split().str.len()

verified_df.head()
# Out:
#     product_id  Review_count        Min  Year    index  customer_id  \
# 14  B000C8XRHS            15 2015-02-17  2015  1075906     50884444
# 13  B000C8XRHS            15 2015-02-17  2015   940252     37453533
# 12  B000C8XRHS            15 2015-02-17  2015   881869     36855749
# 11  B000C8XRHS            15 2015-02-17  2015   870581      2586124
# 10  B000C8XRHS            15 2015-02-17  2015   861058     13517324
#
#          review_id                                    product_title  \
# 14   RJ8BBM1YQS1ZJ  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 13  R1V1CATWFK58NI  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 12  R1J9I5WN2W5YM4  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 11  R30FL2MVJFRLH3  Wagner Lighting 9011 Halogen Capsule - Box of 1
# 10   RTBNC9X1DCQJD  Wagner Lighting 9011 Halogen Capsule - Box of 1
#
#    product_category  star_rating  ...  total_votes  vine verified_purchase  \
# 14       Automotive          5.0  ...          6.0     N                 Y
# 13       Automotive          5.0  ...          1.0     N                 Y
# 12       Automotive          5.0  ...          1.0     N                 Y
# 11       Automotive          5.0  ...          1.0     N                 Y
# 10       Automotive          5.0  ...          0.0     N                 Y
#
#                 review_headline  \
# 14  Genuine Philips 9011 bulbs!
# 13                   Five Stars
# 12            Truely excellent!
# 11     Great deal for the price
# 10                 Great bulbs.
#
#                                           review_body review_date  \
# 14  Awesome deal! I saw that there was a long dela...  2015-02-17
# 13  Brighter than stock 9005, retains proper focus...  2015-03-14
# 12  Well worth the money if your looking for a bri...  2015-03-25
# 11  These are actually Phillips 9011!!!<br />Great...  2015-03-27
# 10              Work great.  These are the real deal.  2015-03-29
#
#    Review_Order  helpfulness_index  Text_Length  Summary_Length
# 14            1               0.83          166               4
# 13            2               0.00           10               2
# 12            3               1.00           22               2
# 11            4               1.00           37               5
# 10            5               0.00            7               2
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Data Export

# %%
final_df = verified_df.sample(frac=1).reset_index(drop=True)

# %%
final_df.to_feather(str('./Data/Filtered_Data/filter_' + str(FILE_NO) + '.feather'))

# %%
## EXPORT THE NOTEBOOK TO A PDF FOR FUTURE REFERENCE
os.system("jupyter-nbconvert General_Data_Extraction_Template.ipynb --to html --output output_file" + str(FILE_NO))
# Out:
# 0
